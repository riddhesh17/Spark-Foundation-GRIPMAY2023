# %% [markdown]
# # Name :- Riddhesh Awade

# %% [markdown]
#  # Task 1:Predict the percentage of a student based on the no. of study hours.

# %% [markdown]
# ![Task1-2.png](attachment:Task1-2.png)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# # Loading Dataset

# %%
url ="http://bit.ly/w-data"
df = pd.read_csv(url)         #Read data from given link(url).

# %%
df.head()  #Show first 5 rows
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# # Let's get stastical information about the dataset

# %%
#number of rows and columns
df.shape
# Out:
# (25, 2)

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.columns    #Display the columns names
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %% [markdown]
# # Checking for Null Values

# %%
df.isnull().sum()      #Sum of null values present
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# **No missing values** present in data

# %% [markdown]
# # Plotting the Data

# %%
df.plot(x='Hours', y='Scores', style='o')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %% [markdown]
# There is a ***Positive linear relatinship*** between the ***number of study hours*** and ***percentage of score.***

# %% [markdown]
# # Preparing the data

# %%
x = df.iloc[:,:-1].values  #Extracts all rows and all columns except for the Last Column
y = df.iloc[:,1].values    #Extracts all rows of the second column

# %% [markdown]
# # Train Test Split

# %% [markdown]
# <ul>
#     <li>Now we will split the data into training and testing sets with splitting rule 80-20.</li>
#     <li>Here we use train_test_split method using sklearn library.</li>
# </ul>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42,shuffle =True)
print(f"Rows in x_train set: {len(x_train)}\nRows in y_train set: {len(y_train)}\n\nRows in x_test set: {len(x_test)}\nRows in y_test: {len(y_test)}")
# Out:
# Rows in x_train set: 20
# Rows in y_train set: 20
#
# Rows in x_test set: 5
# Rows in y_test: 5

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train, y_train)

print("Training Complete.")
# Out:
# Training Complete.

# %%
# Plotting the regression line
line = reg.coef_*x+reg.intercept_

#plotting for the test data
plt.scatter(x,y)
plt.plot(x, line)
plt.show()

# %% [markdown]
# # Prediction with test data

# %%
print(x_test) # Testing dsata  - In Hours
reg_pred = reg.predict(x_test)  # Predicting the scores
# Out:
# [[8.3]
#  [2.5]
#  [2.5]
#  [6.9]
#  [5.9]]

# %%
# Comparing Actual(Y_test)v/s Predicated vaalues (reg_pred).
df = pd.DataFrame({"Actual":y_test,"Predicated":reg_pred})
df
# Out:
#    Actual  Predicated
# 0      81   83.188141
# 1      30   27.032088
# 2      21   27.032088
# 3      76   69.633232
# 4      62   59.951153

# %%
hours = 9.25
own = reg.predict([[hours]])
print(f"Number of hours : {hours}")
print(f"Predicted Scores : {own}")
# Out:
# Number of hours : 9.25
# Predicted Scores : [92.38611528]

# %% [markdown]
# Which shows that if student will study for ***9.25 hours*** he will get percent score of ***92.38%***

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error, r2_score
print("R_square:",r2_score(y_test,reg_pred))
print("Mean squared Error:",mean_squared_error(y_test,reg_pred))
print("Mean Absolute Error",mean_absolute_error(y_test,reg_pred))
# Out:
# R_square: 0.9678055545167994
# Mean squared Error: 18.943211722315272
# Mean Absolute Error 3.9207511902099244

# %% [markdown]
# # 📌 Conclusion
# From the analysis performed above we can conclude following things:
#
# 1.Here_R_Square values is **0.9735** which shows that **97.35%** of variation in the outcome(dependent)variable is explained by independent variable.
#
# 2.Model predicts that if a student studies for ***9.25 hours per day*** then he/she will score ***92.38%.***
